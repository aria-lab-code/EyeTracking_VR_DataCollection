# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable
import os
import torch.onnx

# %% [markdown]
# ## Data Exploration

# %%
dataframes = []
train_data_directory = "../EyeTrackingTest/Data/Train"
for file in os.listdir(train_data_directory):
    dataframes.append(pd.read_csv(os.path.join(train_data_directory, file), delimiter=",").iloc[:,:-1])

# %%
for j in range(len(dataframes)):
    df = dataframes[j]
    labelx = []
    labely = []
    labelz = []
    for i in range(df.shape[0] - 1):
        label_row = df.iloc[i + 1]
        labelx.append(label_row["forward.x"])
        labely.append(label_row["forward.y"])
        labelz.append(label_row["forward.z"])

    df = df.iloc[:-1, :]
    df["label.x"] = labelx
    df["label.y"] = labely
    df["label.z"] = labelz
    dataframes[j] = df

dataframes[0].head(5)
# Out:
#           time(100ns)  time_stamp(ms)  frame  gaze_direct_L.x  \
# 0  638000597804996743           40413    560        -0.023819
# 1  638000597805076741           40421    560        -0.023819
# 2  638000597805166743           40430    561        -0.023788
# 3  638000597805246741           40438    562        -0.023560
# 4  638000597805326743           40446    563        -0.023300
#
#    gaze_direct_L.y  gaze_direct_L.z  gaze_direct_R.x  gaze_direct_R.y  \
# 0         0.115951         0.992966         0.016953         0.111084
# 1         0.116440         0.992905         0.017181         0.109711
# 2         0.116440         0.992905         0.015930         0.109009
# 3         0.115784         0.992981         0.016022         0.109375
# 4         0.115921         0.992981         0.014969         0.108475
#
#    gaze_direct_R.z  forward.x  forward.y  forward.z   label.x   label.y  \
# 0         0.993652   0.013144   0.088526   0.995987  0.013144  0.088526
# 1         0.993805   0.013144   0.088526   0.995987  0.013634  0.088512
# 2         0.993912   0.013634   0.088512   0.995982  0.013643  0.088508
# 3         0.993866   0.013643   0.088508   0.995982  0.013599  0.088151
# 4         0.993973   0.013599   0.088151   0.996014  0.013599  0.088151
#
#     label.z
# 0  0.995987
# 1  0.995982
# 2  0.995982
# 3  0.996014
# 4  0.996014

# %%
df = dataframes[0]
plt.figure(figsize=(10,6))
x = df["time_stamp(ms)"]
plt.xlabel("time_stamp(ms)")

plt.plot(x, df["gaze_direct_L.y"], label = "gaze_direct_L.y")
plt.plot(x, df["forward.y"], label="forward.y")


plt.title("Neck Prediction Y")
plt.legend()
plt.show()

# %%
min_size = float('inf')
for df in dataframes:
    if df.shape[0] < min_size:
        min_size = df.shape[0]

for i in range(len(dataframes)):
    dataframes[i] = dataframes[i][:min_size]
    df = df[:min_size]

# %%
X_series = []
y_series = []
for df in dataframes:
    X = df.iloc[:, 3:-3].to_numpy()
    y = df.iloc[:, -3:].to_numpy()
    
    X = Variable(torch.Tensor(X))
    y = Variable(torch.Tensor(y))
    
    X = torch.reshape(X, (X.shape[0], 1, X.shape[1]))
    X_series.append(X)
    y_series.append(y)
X_series = torch.cat(X_series, dim=1)
y_series = torch.stack(y_series, dim=1)
print(X_series.shape, y_series.shape)
# Out:
# torch.Size([7195, 9, 9]) torch.Size([7195, 9, 3])

# %% [markdown]
# ## LSTM Model

# %%
class CustomLSTM(nn.Module):
    def __init__(self, input_size, output_size=3, hidden_size=9):
        super(CustomLSTM, self).__init__()
        self.num_classes = output_size
        self.num_layers = 1
        self.input_size = input_size
        self.hidden_size = hidden_size
        
        self.lstm = nn.LSTM(input_size=self.input_size, hidden_size=self.hidden_size, num_layers=self.num_layers, batch_first=True)
        self.fc = nn.Sequential(
            nn.Tanh(),
            nn.Linear(self.hidden_size, 128),
            nn.Tanh(),
            nn.Linear(128, self.num_classes)
        )
    
    def forward(self, x, h_0=None, c_0=None):
        if h_0 is None:
            h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(torch.device("cuda"))
        if c_0 is None:
            c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(torch.device("cuda"))
        
        output, (hn, cn) = self.lstm(x, (h_0, c_0))
        _hn = hn.view(-1, self.hidden_size)
        out = self.fc(_hn)
        return out, hn, cn

# %% [markdown]
# ## Training Loop and Results

# %%
def train(model, X, y, optimizer, criterion, device):
    model.train()
    optimizer.zero_grad()
    preds = torch.zeros(y.shape).to(device)
    for j in range(X.shape[1]):
        instance = X[0:1, j:j+1, :]
        hn = None
        cn = None
        for i in range(6000):
            pred, hn, cn = model(instance, hn, cn)
            pred = nn.functional.normalize(pred)
            preds[i, j] = pred
            #cur_loss = criterion(pred, y[i:i+1, j])
            #loss += criterion(pred, y[i:i+1, j]) / (6000 * X.shape[1])
            #losses.append(cur_loss.item())
            
            if i < 5999:
                l_pred = nn.functional.normalize(torch.reshape(X[i+1,j:j+1,6:9] + X[i+1,j:j+1,0:3] - pred[0], (1,3)))
                r_pred = nn.functional.normalize(torch.reshape(X[i+1,j:j+1,6:9] + X[i+1,j:j+1,3:6] - pred[0], (1,3)))
                instance = torch.reshape(torch.cat((l_pred, r_pred, pred), axis=1), (1,1,9))
    loss = criterion(preds[:6000], y[:6000])
    loss.backward()
    optimizer.step()
    return loss.item()

# %%
def val(model, X, y, criterion, device):
    model.eval()
    preds = torch.zeros(y.shape).to(device)
    for j in range(X.shape[1]):
        instance = X[0:1, j:j+1, :]
        hn = None
        cn = None
        for i in range(X.shape[0]):
            pred, hn, cn = model(instance, hn, cn)
            pred = nn.functional.normalize(pred)
            preds[i, j] = pred
            if i < X.shape[0] - 1:
                l_pred = nn.functional.normalize(torch.reshape(X[i+1,j:j+1,6:9] + X[i+1,j:j+1,0:3] - pred[0], (1,3)))
                r_pred = nn.functional.normalize(torch.reshape(X[i+1,j:j+1,6:9] + X[i+1,j:j+1,3:6] - pred[0], (1,3)))
                instance = torch.reshape(torch.cat((l_pred, r_pred, pred), axis=1), (1,1,9))
    loss = criterion(preds[6000:], y[6000:])
    return loss.item()

# %%
def train_loop(model, X, y, optimizer, device, scheduler, num_epochs):
    train_losses = []
    val_losses = []
    counter = 0
    X = X.to(device)
    y = y.to(device)
    min_val_loss = val(model, X, y, criterion, device)
    for epoch in range(num_epochs):
        train_loss = train(model, X, y, optimizer, criterion, device)
        train_losses.append(train_loss)
        
        val_loss = val(model, X, y, criterion, device)
        val_losses.append(val_loss)
        
        print("Epoch: %d, train loss: %1.5f, val loss: %1.5f" % (epoch, train_loss, 
                                                                 val_losses[epoch]))
        if val_losses[epoch] < min_val_loss:
            min_val_loss = val_losses[epoch]
            counter = 0
            torch.save(model.state_dict(), "best_val.pth")
        else:
            counter += 1
            if counter > 10:
                break
        
        if epoch % 10 == 0:
            scheduler.step()
        
    return train_losses, val_losses

# %%
learning_rate = 0.001
criterion = torch.nn.MSELoss()

device = torch.device("cuda")

lr_xyz = CustomLSTM(input_size=9).to(device)
optimizer = torch.optim.Adam(lr_xyz.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %%
train_losses, val_losses = train_loop(lr_xyz, X_series, y_series, optimizer, device, scheduler, 1000)
# Out:
# Epoch: 0, train loss: 0.78060, val loss: 0.74829
# Epoch: 1, train loss: 0.69454, val loss: 0.67660
# Epoch: 2, train loss: 0.62409, val loss: 0.61053
# Epoch: 3, train loss: 0.56128, val loss: 0.55009
# Epoch: 4, train loss: 0.50544, val loss: 0.49467
# Epoch: 5, train loss: 0.45533, val loss: 0.44296
# Epoch: 6, train loss: 0.40928, val loss: 0.39392
# Epoch: 7, train loss: 0.36609, val loss: 0.34707
# Epoch: 8, train loss: 0.32523, val loss: 0.30301
# Epoch: 9, train loss: 0.28711, val loss: 0.26276
# Epoch: 10, train loss: 0.25245, val loss: 0.22766
# Epoch: 11, train loss: 0.22224, val loss: 0.20126
# Epoch: 12, train loss: 0.19942, val loss: 0.18003
# Epoch: 13, train loss: 0.18095, val loss: 0.16387
# Epoch: 14, train loss: 0.16682, val loss: 0.15229
# Epoch: 15, train loss: 0.15666, val loss: 0.14465
# Epoch: 16, train loss: 0.14994, val loss: 0.14007
# Epoch: 17, train loss: 0.14586, val loss: 0.13776
# Epoch: 18, train loss: 0.14369, val loss: 0.13689
# Epoch: 19, train loss: 0.14268, val loss: 0.13677
# Epoch: 20, train loss: 0.14224, val loss: 0.13693
# Epoch: 21, train loss: 0.14197, val loss: 0.13693
# Epoch: 22, train loss: 0.14158, val loss: 0.13665
# Epoch: 23, train loss: 0.14093, val loss: 0.13599
# Epoch: 24, train loss: 0.13996, val loss: 0.13485
# Epoch: 25, train loss: 0.13863, val loss: 0.13337
# Epoch: 26, train loss: 0.13701, val loss: 0.13160
# Epoch: 27, train loss: 0.13520, val loss: 0.12962
# Epoch: 28, train loss: 0.13322, val loss: 0.12749
# Epoch: 29, train loss: 0.13114, val loss: 0.12533
# Epoch: 30, train loss: 0.12905, val loss: 0.12314
# Epoch: 31, train loss: 0.12697, val loss: 0.12123
# Epoch: 32, train loss: 0.12516, val loss: 0.11939
# Epoch: 33, train loss: 0.12340, val loss: 0.11764
# Epoch: 34, train loss: 0.12172, val loss: 0.11600
# Epoch: 35, train loss: 0.12013, val loss: 0.11448
# Epoch: 36, train loss: 0.11864, val loss: 0.11305
# Epoch: 37, train loss: 0.11722, val loss: 0.11173
# Epoch: 38, train loss: 0.11587, val loss: 0.11051
# Epoch: 39, train loss: 0.11459, val loss: 0.10935
# Epoch: 40, train loss: 0.11337, val loss: 0.10826
# Epoch: 940, train loss: 0.01169, val loss: 0.01131
# Epoch: 941, train loss: 0.01169, val loss: 0.01131
# Epoch: 942, train loss: 0.01169, val loss: 0.01131
# Epoch: 943, train loss: 0.01169, val loss: 0.01131
# Epoch: 944, train loss: 0.01169, val loss: 0.01131
# Epoch: 945, train loss: 0.01169, val loss: 0.01131
# Epoch: 946, train loss: 0.01169, val loss: 0.01131
# Epoch: 947, train loss: 0.01169, val loss: 0.01131
# Epoch: 948, train loss: 0.01169, val loss: 0.01131
# Epoch: 949, train loss: 0.01169, val loss: 0.01131
# Epoch: 950, train loss: 0.01169, val loss: 0.01131
# Epoch: 951, train loss: 0.01169, val loss: 0.01131
# Epoch: 952, train loss: 0.01169, val loss: 0.01131
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 train_losses, val_losses = train_loop(lr_xyz, X_series, y_series, optimizer, device, scheduler, 1000)
#
# Cell In[10], line 12, in train_loop(model, X, y, optimizer, device, scheduler, num_epochs)
#       9 train_loss = train(model, X, y, optimizer, criterion, device)
#      10 train_losses.append(train_loss)
# ---> 12 val_loss = val(model, X, y, criterion, device)
#      13 val_losses.append(val_loss)
#      15 print("Epoch: %d, train loss: %1.5f, val loss: %1.5f" % (epoch, train_loss,
#      16                                                          val_losses[epoch]))
#
# Cell In[9], line 10, in val(model, X, y, criterion, device)
#       8 for i in range(X.shape[0]):
#       9     pred, hn, cn = model(instance, hn, cn)
# ---> 10     pred = nn.functional.normalize(pred)
#      11     preds[i, j] = pred
#      12     if i < X.shape[0] - 1:
#
# File ~\Anaconda3\envs\EyeTracking\lib\site-packages\torch\nn\functional.py:4632, in normalize(input, p, dim, eps, out)
#    4630     return handle_torch_function(normalize, (input, out), input, p=p, dim=dim, eps=eps, out=out)
#    4631 if out is None:
# -> 4632     denom = input.norm(p, dim, keepdim=True).clamp_min(eps).expand_as(input)
#    4633     return input / denom
#    4634 else:
#
# File ~\Anaconda3\envs\EyeTracking\lib\site-packages\torch\_tensor.py:638, in Tensor.norm(self, p, dim, keepdim, dtype)
#     634 if has_torch_function_unary(self):
#     635     return handle_torch_function(
#     636         Tensor.norm, (self,), self, p=p, dim=dim, keepdim=keepdim, dtype=dtype
#     637     )
# --> 638 return torch.norm(self, p, dim, keepdim, dtype=dtype)
#
# File ~\Anaconda3\envs\EyeTracking\lib\site-packages\torch\functional.py:1529, in norm(input, p, dim, keepdim, out, dtype)
#    1527 if out is None:
#    1528     if dtype is None:
# -> 1529         return _VF.norm(input, p, _dim, keepdim=keepdim)  # type: ignore[attr-defined]
#    1530     else:
#    1531         return _VF.norm(input, p, _dim, keepdim=keepdim, dtype=dtype)  # type: ignore[attr-defined]
#
# KeyboardInterrupt:

# %%
lr_xyz = CustomLSTM(input_size=9).to(device)
lr_xyz.load_state_dict(torch.load("best_val.pth"))
# Out:
# <All keys matched successfully>

# %%
torch.onnx.export(lr_xyz.cpu(),               # model being run
                  (X[0:1, 0:1, :], torch.zeros(1, 1, 9), torch.zeros(1, 1, 9)), # model input (or a tuple for multiple inputs)
                  "lr_xyz.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=10,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input', 'h0', 'c0'],   # the model's input names
                  output_names = ['output', 'hn', 'cn']) # the model's output names
# Out:
# C:\Users\Brown Research\Anaconda3\envs\EyeTracking\lib\site-packages\torch\onnx\symbolic_opset9.py:4315: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# C:\Users\Brown Research\Anaconda3\envs\EyeTracking\lib\site-packages\torch\onnx\_internal\jit_utils.py:258: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\shape_type_inference.cpp:1888.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# C:\Users\Brown Research\Anaconda3\envs\EyeTracking\lib\site-packages\torch\onnx\utils.py:687: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\shape_type_inference.cpp:1888.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# C:\Users\Brown Research\Anaconda3\envs\EyeTracking\lib\site-packages\torch\onnx\utils.py:1178: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\shape_type_inference.cpp:1888.)
#   _C._jit_pass_onnx_graph_shape_type_inference(

# %%
X = X_series[:, 3:4, :]
y = y_series[:, 3, :]

print(X.shape, y.shape)
lr_xyz.to(device)
# Out:
# torch.Size([7195, 1, 9]) torch.Size([7195, 3])
# CustomLSTM(
#   (lstm): LSTM(9, 9, batch_first=True)
#   (fc): Sequential(
#     (0): Tanh()
#     (1): Linear(in_features=9, out_features=128, bias=True)
#     (2): Tanh()
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )

# %%
train_predict, _, _ = lr_xyz(X.to(device))
data_predict = np.array([X[0, 0, 6:9].data.numpy()])
data_predict = np.append(data_predict, train_predict.data.cpu().numpy(), axis=0)

dataY_plot = np.array([X[0, 0, 6:9].data.numpy()])
dataY_plot = np.append(dataY_plot, y.data.numpy(), axis=0)
print(data_predict.shape, dataY_plot.shape)
# Out:
# (7196, 3) (7196, 3)

# %%
data_compound = [X[0, 0, 6:9].data.numpy()]
hn = None
cn = None
for i in range(X.size(0)):
    instance = X[i:i+1]
    pred, hn, cn = lr_xyz(instance.to(device), hn, cn)
    pred = nn.functional.normalize(pred)
    pred = pred.data.cpu().numpy()
    cur = X[i, 0, 6:9].data.numpy()
    data_compound.append(pred[0])
    if i < X.size(0) - 1:
        X[i+1,0,0:3] = nn.functional.normalize(torch.reshape(X[i+1,0,6:9] + X[i+1,0,0:3] - torch.Tensor(pred[0]), (1,3))).view(-1,3)
        X[i+1,0,3:6] = nn.functional.normalize(torch.reshape(X[i+1,0,6:9] + X[i+1,0,3:6] - torch.Tensor(pred[0]), (1,3))).view(-1,3)
        X[i+1,0,6] = pred[0,0].item()
        X[i+1,0,7] = pred[0,1].item()
        X[i+1,0,8] = pred[0,2].item()
data_compound = np.array(data_compound)
print(data_compound.shape)
# Out:
# (7196, 3)

# %%
plt.figure(figsize=(10,6))
plt.axvline(x=6000, c='r', linestyle="--")

plt.plot(dataY_plot[:, 0], label="Actual Data")
#plt.plot(data_predict[:, 0], label="Predicted Data")
plt.plot(data_compound[:, 0], label="Compounded Data")
plt.title("Neck Prediction X")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.axvline(x=6000, c='r', linestyle="--")

plt.plot(dataY_plot[:, 1], label="Actual Data")
#plt.plot(data_predict[:, 1], label="Predicted Data")
plt.plot(data_compound[:, 1], label="Compounded Data")
plt.title("Neck Prediction Y")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.axvline(x=6000, c='r', linestyle="--")

plt.plot(dataY_plot[:, 2], label="Actual Data")
#plt.plot(data_predict[:, 2], label="Predicted Data")
plt.plot(data_compound[:, 2], label="Compounded Data")
plt.title("Neck Prediction Z")
plt.legend()
plt.show()

# %% [markdown]
# ## Testing on New Series

# %%
df = pd.read_csv("../EyeTrackingTest/Data/Test/1_0.txt", delimiter=",").iloc[:, :-1]

# %%
labelx = []
labely = []
labelz = []
for i in range(df.shape[0] - 1):
    label_row = df.iloc[i + 1]
    labelx.append(label_row["forward.x"])
    labely.append(label_row["forward.y"])
    labelz.append(label_row["forward.z"])
    
df = df.iloc[:-1, :]
df["label.x"] = labelx
df["label.y"] = labely
df["label.z"] = labelz
df.head(5)

# %%
X = df.iloc[:, 3:-3].to_numpy()
y = df.iloc[:, -3:].to_numpy()

print(X.shape, y.shape)

# %%
X = Variable(torch.Tensor(X))
y = Variable(torch.Tensor(y))

X = torch.reshape(X, (X.shape[0], 1, X.shape[1]))

# %%
train_predict, _, _ = lr_xyz(X.to(device))
data_predict = train_predict.data.cpu().numpy()
dataY_plot = y.data.numpy()

data_compound = [X[0, 0, 6:9].data.numpy()]
hn = None
cn = None
for i in range(X.size(0)):
    instance = X[i:i+1]
    pred, hn, cn = lr_xyz(instance.to(device), hn, cn)
    pred = pred.data.cpu().numpy()
    cur = X[i, 0, 6:9].data.numpy()
    data_compound.append(pred[0])
    if i < X.size(0) - 1:
        X[i+1,0,0:3] = nn.functional.normalize(torch.reshape(X[i+1,0,6:9] + X[i+1,0,0:3] - torch.Tensor(pred[0]), (1,3))).view(-1,3)
        X[i+1,0,3:6] = nn.functional.normalize(torch.reshape(X[i+1,0,6:9] + X[i+1,0,3:6] - torch.Tensor(pred[0]), (1,3))).view(-1,3)
        X[i+1,0,6] = pred[0,0].item()
        X[i+1,0,7] = pred[0,1].item()
        X[i+1,0,8] = pred[0,2].item()
data_compound = np.array(data_compound)
print(data_compound.shape)

plt.figure(figsize=(10,6))

plt.plot(data)
plt.plot(dataY_plot[:, 0], label="Actual Data")
plt.plot(data_compound[:, 0], label="Predicted Data")
plt.title("Neck Prediction X")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(dataY_plot[:, 1], label="Actual Data")
plt.plot(data_compound[:, 1], label="Predicted Data")
plt.title("Neck Prediction Y")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(dataY_plot[:, 2], label="Actual Data")
plt.plot(data_compound[:, 2], label="Predicted Data")
plt.title("Neck Prediction Z")
plt.legend()
plt.show()
